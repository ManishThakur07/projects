# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import joblib

# %%
df = pd.read_csv("MLRdata.csv")
df
# Out:
#      Unnamed: 0         V1  V2  V3  V4        V5        V6        V7         V8
# 0             1  70.157664   1  10   6  0.672347  2.239792  0.637664  -3.841915
# 1             2  75.172848   1  10   4  0.251939  1.810250  1.050037   8.391126
# 2             3  73.492166   1   8   6  0.281328  2.247168  0.947496   3.917238
# 3             4  71.656961   1  10   7  0.328874  2.478223  0.361662  -5.056545
# 4             5  65.998205   1   8   4  0.364254  1.679748  0.575510  10.065619
# ..          ...        ...  ..  ..  ..       ...       ...       ...        ...
# 995         996  97.676042   1  11  10  0.395040  3.397482  0.576917  -0.204566
# 996         997  77.485497   1   9   4  0.449477  2.044273  1.221810  12.308334
# 997         998  76.770454   1   8   6  0.212692  2.252006  0.735712   9.010854
# 998         999  55.768957   1  10   2  0.659055  1.274611  1.110855  -1.232266
# 999        1000  61.109213   1   8   3  0.441802  1.141352  0.542655  10.944478
#
# [1000 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1000 non-null   int64
#  1   V1          1000 non-null   float64
#  2   V2          1000 non-null   int64
#  3   V3          1000 non-null   int64
#  4   V4          1000 non-null   int64
#  5   V5          1000 non-null   float64
#  6   V6          1000 non-null   float64
#  7   V7          1000 non-null   float64
#  8   V8          1000 non-null   float64
# dtypes: float64(5), int64(4)
# memory usage: 70.4 KB

# %%
sns.heatmap(df)
# Out:
# <Axes: >

# %%
x = df.iloc[:,0:8]
y = df.iloc[:,-1]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predic = lr.predict(x_test)
predic
# Out:
# array([ 4.13326768,  4.01316424,  4.1027552 ,  6.38375505,  4.49879428,
#         5.62477674,  9.53256377,  3.8986293 ,  4.33142044,  3.78386158,
#         3.3558975 ,  3.10602987,  6.39025584,  2.94194376,  2.89477759,
#         3.52046283,  3.65939472,  4.96759501,  7.85137122,  3.03059832,
#         4.5103296 ,  4.3342337 ,  2.49993758,  3.01291756,  3.37158605,
#         3.91564877,  5.4912165 ,  2.27034776,  2.2833556 ,  4.40296414,
#         3.15574255,  4.53991606,  5.92737916,  3.56181331,  3.28290879,
#         2.25716675,  7.76531015,  4.53922683,  2.47737411,  4.24126467,
#         3.35224987,  4.34953129,  4.69521723,  3.24064737,  4.02316656,
#         3.57603937,  4.04591101,  6.14722862,  3.63436496,  4.66604521,
#         5.02007397,  2.26317841,  1.90406548,  4.44574469,  4.75623115,
#         4.5869923 ,  3.07468322,  6.23534417,  4.31380746,  3.54426152,
#         5.21883394,  2.32941171,  4.241789  ,  4.36872134,  5.03574755,
#         6.25270676,  6.97770597,  4.37601832,  4.00614733,  2.83570736,
#         4.19013638,  3.57644919,  3.33108396, 10.90090928,  3.48761876,
#         5.40798268, 13.00918766,  4.27581425,  3.64237966,  3.66106736,
#         5.34023834,  3.29565737,  4.77275474,  5.54614445,  4.0239214 ,
#         4.24894906,  2.98886491, 19.1716675 ,  5.65117707,  5.03930644,
#         4.53361303,  5.08039401,  4.03303966,  4.21836887,  9.02472971,
#         3.74025884,  9.20423656,  2.9538576 ,  3.36964872,  3.92456955,
#         5.35944834,  5.28783432,  5.10090246,  4.90354252,  9.59873321,
#        19.74475844,  3.29591818,  1.97708644,  3.36649591,  5.19696176,
#         4.14882201,  5.5484274 ,  4.38120719,  3.09336861,  5.74456918,
#         2.39811935,  3.80871388,  3.85908015,  4.84838607,  5.92368065,
#         3.87029726,  4.44858888,  6.44166215,  3.68278642,  4.77977897,
#         4.38805428,  3.63411696,  3.59054356,  4.19879697,  3.30812743,
#         4.65717681,  3.23582457,  4.83266849,  3.34550379,  5.130247  ,
#         4.40480454,  4.2798571 ,  2.82791736,  4.96750266,  4.8713058 ,
#         5.1279106 ,  4.52621604,  7.01232947,  2.50543981,  2.92375991,
#         3.43703529,  3.58098488,  4.85318399,  1.97554322,  4.18523952,
#        15.56691229,  4.1360276 ,  2.60727846,  4.85618801,  4.60891731,
#         2.84306067,  4.81324639,  7.42475274,  3.57066836,  3.29771398,
#         5.18614694,  9.39486632,  5.54904703,  4.42550018,  4.21524982,
#        26.48717664,  4.54835015,  4.08782555,  5.23488967,  5.16285755,
#         3.91233879,  3.56448511,  4.90897291,  4.22462714,  3.34627778,
#         5.20726063,  5.36529174,  4.58582187,  3.05071963,  6.34003733,
#         3.26893376,  7.20627646,  3.9796274 ,  4.64492848,  4.44869245,
#         4.38807493,  4.66651331,  4.43482519,  3.14933756,  5.93643712,
#         4.68244909,  4.5698326 ,  4.06766693,  3.39079745,  2.92881612,
#         2.75958652,  3.65093402,  4.38869457,  8.32614785,  4.88651824])

# %%
# y = b1x1 + b2x2 + b3x3 + bo
bm = lr.coef_
bo = lr.intercept_
b1 = bm[0]
b2 = bm[1]
b3 = bm[2]
b4 = bm[3]
b5 = bm[4] 
b6 = bm[5]
b7 = bm[6]
b8 = bm[7]
y = (b1*1) + (b2*70.157664) + (b3*1) + (b4*10) + (b5*6) + (b6*0.672347) + (b7*2.239792) + (b8*0.637664) + bo 
y
# Out:
# np.float64(3.732576135381054)

# %%
r2_score(y_test,predic)
# Out:
# 0.06441202828456427

# %%
joblib.dump(lr,"MLRdata.joblib")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 joblib.dump(lr,"MLRdata.joblib")
#
# NameError: name 'joblib' is not defined
