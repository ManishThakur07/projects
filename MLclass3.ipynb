# %%
import pandas as pd

# %%
df = pd.read_csv("cancer issue.csv")
df
# Out:
#        PatientID  Age  Gender    Race/Ethnicity   BMI  SmokingStatus  \
# 0              1   80  Female             Other  23.3         Smoker
# 1              2   76    Male         Caucasian  22.4  Former Smoker
# 2              3   69    Male             Asian  21.5         Smoker
# 3              4   77    Male             Asian  30.4  Former Smoker
# 4              5   89    Male         Caucasian  20.9         Smoker
# ...          ...  ...     ...               ...   ...            ...
# 17681      17682   48    Male         Caucasian  35.3     Non-Smoker
# 17682      17683   83  Female             Other  32.5         Smoker
# 17683      17684   86    Male         Caucasian  39.8  Former Smoker
# 17684      17685   77  Female  African American  37.9  Former Smoker
# 17685      17686   80  Female  African American  29.3     Non-Smoker
#
#       FamilyHistory CancerType Stage  TumorSize        TreatmentType  \
# ...

# %%
da = df.drop(columns=["GeneticMarker","SurvivalMonths","Age","BMI"])
da
# Out:
#        PatientID  Gender    Race/Ethnicity  SmokingStatus FamilyHistory  \
# 0              1  Female             Other         Smoker           Yes
# 1              2    Male         Caucasian  Former Smoker           Yes
# 2              3    Male             Asian         Smoker           Yes
# 3              4    Male             Asian  Former Smoker           Yes
# 4              5    Male         Caucasian         Smoker           Yes
# ...          ...     ...               ...            ...           ...
# 17681      17682    Male         Caucasian     Non-Smoker            No
# 17682      17683  Female             Other         Smoker            No
# 17683      17684    Male         Caucasian  Former Smoker            No
# 17684      17685  Female  African American  Former Smoker           Yes
# 17685      17686  Female  African American     Non-Smoker           Yes
#
#       CancerType Stage  TumorSize        TreatmentType   TreatmentResponse  \
# ...

# %%
da.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17686 entries, 0 to 17685
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PatientID          17686 non-null  int64
#  1   Gender             17686 non-null  object
#  2   Race/Ethnicity     17686 non-null  object
#  3   SmokingStatus      17686 non-null  object
#  4   FamilyHistory      17686 non-null  object
#  5   CancerType         17686 non-null  object
#  6   Stage              17686 non-null  object
#  7   TumorSize          17686 non-null  float64
#  8   TreatmentType      17686 non-null  object
#  9   TreatmentResponse  17686 non-null  object
#  10  Recurrence         17686 non-null  object
#  11  HospitalRegion     17686 non-null  object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 1.6+ MB

# %%
x = da.iloc[:,1]
x
# Out:
# 0        Female
# 1          Male
# 2          Male
# 3          Male
# 4          Male
#           ...
# 17681      Male
# 17682    Female
# 17683      Male
# 17684    Female
# 17685    Female
# Name: Gender, Length: 17686, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder,OrdinalEncoder,OneHotEncoder

# %%
le = LabelEncoder()
oe = OrdinalEncoder()
ohe = OneHotEncoder()

# %%
le.fit_transform(x)
# Out:
# array([0, 1, 1, ..., 1, 0, 0])

# %%
y = da.iloc[:,2:4]
y
# Out:
#          Race/Ethnicity  SmokingStatus
# 0                 Other         Smoker
# 1             Caucasian  Former Smoker
# 2                 Asian         Smoker
# 3                 Asian  Former Smoker
# 4             Caucasian         Smoker
# ...                 ...            ...
# 17681         Caucasian     Non-Smoker
# 17682             Other         Smoker
# 17683         Caucasian  Former Smoker
# 17684  African American  Former Smoker
# 17685  African American     Non-Smoker
#
# [17686 rows x 2 columns]

# %%
xx = OrdinalEncoder(categories=[""])
oe.fit_transform(y)
# Out:
# array([[4., 2.],
#        [2., 0.],
#        [1., 2.],
#        ...,
#        [2., 0.],
#        [0., 0.],
#        [0., 1.]])
